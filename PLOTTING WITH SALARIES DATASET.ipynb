# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Salaries.csv')

# %%
print(data['BasePay'])
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
# 5         118602.00
# 6          92492.01
# 7         256576.96
# 8         176932.64
# 9         285262.00
# 10        194999.39
# 11         99722.00
# 12        294580.02
# 13        271329.03
# 14        174872.64
# 15        198778.01
# 16        268604.57
# 17        140546.87
# 18        168692.63
# 19        257510.59
# 20        257510.48
# 21        257510.44
# 22        140546.88
# 23        168692.63
# 24        140546.86
# 25        256470.41
# 26         92080.80
# 27        168692.59
# 28        261717.60
# 29        246225.60
#             ...
# 148624         0.00
# 148625         0.00
# 148626         0.00
# 148627         0.00
# 148628         0.00
# 148629         0.00
# 148630         0.00
# 148631         0.00
# 148632         0.00
# 148633         0.00
# 148634         0.00
# 148635         0.00
# 148636         0.00
# 148637         0.00
# ...

# %%
data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
print(data['TotalPay'])
# Out:
# 0         567595.43
# 1         538909.28
# 2         335279.91
# 3         332343.61
# 4         326373.19
# 5         316285.74
# 6         315981.05
# 7         307899.46
# 8         303427.55
# 9         302377.73
# 10        299494.17
# 11        297608.92
# 12        294580.02
# 13        292671.62
# 14        286347.05
# 15        286213.86
# 16        284720.43
# 17        278569.21
# 18        276434.22
# 19        274550.25
# 20        274190.27
# 21        273771.21
# 22        273702.71
# 23        270672.63
# 24        270324.91
# 25        267992.59
# 26        265784.56
# 27        265463.46
# 28        264074.60
# 29        261366.14
#             ...
# 148624        12.89
# 148625         6.00
# 148626         0.00
# 148627         0.00
# 148628         0.00
# 148629         0.00
# 148630         0.00
# 148631         0.00
# 148632         0.00
# 148633         0.00
# 148634         0.00
# 148635         0.00
# 148636         0.00
# 148637         0.00
# ...

# %%
plt.plot(data['BasePay'],'r')
plt.show()

# %%
plt.plot(data['TotalPay'],color='r')
plt.show()

# %%
plt.plot(data['BasePay'],data['TotalPay'],color='b')

# %%
data=data.head(50)

# %%
plt.scatter(data['BasePay'],data['TotalPay'],color='b')

# %%
plt.scatter(data['BasePay'],data['TotalPay'],color='b')
plt.plot(data['BasePay'],data['TotalPay'],color='r')

# %%
plt.scatter(data['BasePay'],data['TotalPay'],color='b',label='line graph')
plt.plot(data['BasePay'],data['TotalPay'],color='r',label='scatter')
plt.legend(loc=5)

# %%
plt.scatter(data['BasePay'],data['TotalPay'],color='b',label='line graph')
plt.plot(data['BasePay'],data['TotalPay'],color='r',label='scatter')
plt.xlabel('Base-pay', color='green')
plt.xlabel('Total-pay', color='orange')
plt.title('BASE-PAY VS TOTAL-PAY', color='blue')
plt.legend()

# %%
plt.bar(data['BasePay'],data['TotalPay'],color='b',label='line graph')
#plt.plot(data['BasePay'],data['TotalPay'],color='r',label='scatter')
plt.xlabel('Base-pay', color='green')
plt.ylabel('Total-pay', color='orange')
plt.title('BASE-PAY VS TOTAL-PAY', color='blue')
plt.legend()

# %%
fig=plt.figure()

g1= fig.add_subplot(1,2,1)
g1.plot(data['BasePay'],data['TotalPay'])
g1.scatter(data['BasePay'],data['TotalPay'],color='pink')


g2= fig.add_subplot(1,2,2)
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

plt.tight_layout()

# %%
fig=plt.figure()

g1= fig.add_subplot(2,1,1)
g1.plot(data['BasePay'],data['TotalPay'])
g1.scatter(data['BasePay'],data['TotalPay'],color='pink')


g2= fig.add_subplot(2,1,2)
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

# %%
fig=plt.figure()

g1= fig.add_subplot(2,1,1)
g1.plot(data['BasePay'],data['TotalPay'])
g1.scatter(data['BasePay'],data['TotalPay'],color='pink')


g2= fig.add_subplot(2,1,2)
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

plt.tight_layout()

# %%
fig=plt.figure()

g1= fig.add_subplot(2,2,1)
g1.plot(data['BasePay'],data['TotalPay'])
g1.scatter(data['BasePay'],data['TotalPay'],color='pink')


g2= fig.add_subplot(2,2,2)
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

g3= fig.add_subplot(2,2,3)
g3.plot(data['OtherPay'],data['TotalPay'],color='red')
g3.scatter(data['OtherPay'],data['TotalPay'])

g4= fig.add_subplot(2,2,4)
g4.plot(data['BasePay'],data['TotalPay'])
g4.scatter(data['BasePay'],data['TotalPay'],color='pink')


plt.tight_layout()

# %%
fig=plt.figure()

g1= fig.add_subplot(2,2,1)
g1.plot(data['BasePay'],data['TotalPay'])
g1.scatter(data['BasePay'],data['TotalPay'],color='pink')


g2= fig.add_subplot(2,2,2)
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

g2= fig.add_subplot(2,1,2)
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

plt.tight_layout()

# %%
fig=plt.figure()

fig.patch.set_facecolor('gray')

g1= fig.add_subplot(2,2,1)
g1.plot(data['BasePay'],data['TotalPay'])
g1.scatter(data['BasePay'],data['TotalPay'],color='pink')


g2= fig.add_subplot(2,2,2)
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

g2= fig.add_subplot(2,1,2)
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

# %%
fig=plt.figure()

fig.patch.set_facecolor('gray')

g1= fig.add_subplot(2,2,1,facecolor='blue')
g1.plot(data['BasePay'],data['TotalPay'])
g1.scatter(data['BasePay'],data['TotalPay'],color='pink')


g2= fig.add_subplot(2,2,2,facecolor='red')
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

g3= fig.add_subplot(2,1,2,facecolor='orange')
g3.plot(data['OtherPay'],data['TotalPay'],color='green')
g3.scatter(data['OtherPay'],data['TotalPay'])

# %%
import time
from math import pi
x=np.linspace(-2*pi,2*pi,360)
fx=np.sin(x)
plt.plot(x,fx)
plt.show()
print(x)
# Out:
# [-6.28318531 -6.24818149 -6.21317767 -6.17817385 -6.14317004 -6.10816622
#  -6.0731624  -6.03815858 -6.00315476 -5.96815095 -5.93314713 -5.89814331
#  -5.86313949 -5.82813567 -5.79313186 -5.75812804 -5.72312422 -5.6881204
#  -5.65311659 -5.61811277 -5.58310895 -5.54810513 -5.51310131 -5.4780975
#  -5.44309368 -5.40808986 -5.37308604 -5.33808222 -5.30307841 -5.26807459
#  -5.23307077 -5.19806695 -5.16306314 -5.12805932 -5.0930555  -5.05805168
#  -5.02304786 -4.98804405 -4.95304023 -4.91803641 -4.88303259 -4.84802877
#  -4.81302496 -4.77802114 -4.74301732 -4.7080135  -4.67300969 -4.63800587
#  -4.60300205 -4.56799823 -4.53299441 -4.4979906  -4.46298678 -4.42798296
#  -4.39297914 -4.35797532 -4.32297151 -4.28796769 -4.25296387 -4.21796005
#  -4.18295624 -4.14795242 -4.1129486  -4.07794478 -4.04294096 -4.00793715
#  -3.97293333 -3.93792951 -3.90292569 -3.86792187 -3.83291806 -3.79791424
#  -3.76291042 -3.7279066  -3.69290278 -3.65789897 -3.62289515 -3.58789133
# ...

# %%
import time
from math import pi
x=np.linspace(-2*pi,2*pi,360)
fx=np.cos(x)
plt.plot(x,fx)
plt.show()
print(x)
# Out:
# [-6.28318531 -6.24818149 -6.21317767 -6.17817385 -6.14317004 -6.10816622
#  -6.0731624  -6.03815858 -6.00315476 -5.96815095 -5.93314713 -5.89814331
#  -5.86313949 -5.82813567 -5.79313186 -5.75812804 -5.72312422 -5.6881204
#  -5.65311659 -5.61811277 -5.58310895 -5.54810513 -5.51310131 -5.4780975
#  -5.44309368 -5.40808986 -5.37308604 -5.33808222 -5.30307841 -5.26807459
#  -5.23307077 -5.19806695 -5.16306314 -5.12805932 -5.0930555  -5.05805168
#  -5.02304786 -4.98804405 -4.95304023 -4.91803641 -4.88303259 -4.84802877
#  -4.81302496 -4.77802114 -4.74301732 -4.7080135  -4.67300969 -4.63800587
#  -4.60300205 -4.56799823 -4.53299441 -4.4979906  -4.46298678 -4.42798296
#  -4.39297914 -4.35797532 -4.32297151 -4.28796769 -4.25296387 -4.21796005
#  -4.18295624 -4.14795242 -4.1129486  -4.07794478 -4.04294096 -4.00793715
#  -3.97293333 -3.93792951 -3.90292569 -3.86792187 -3.83291806 -3.79791424
#  -3.76291042 -3.7279066  -3.69290278 -3.65789897 -3.62289515 -3.58789133
# ...

# %%
import time
from math import pi
x=np.linspace(-2*pi,2*pi,360)
fx=np.tan(x)
plt.plot(x,fx)
plt.show()
print(x)
# Out:
# [-6.28318531 -6.24818149 -6.21317767 -6.17817385 -6.14317004 -6.10816622
#  -6.0731624  -6.03815858 -6.00315476 -5.96815095 -5.93314713 -5.89814331
#  -5.86313949 -5.82813567 -5.79313186 -5.75812804 -5.72312422 -5.6881204
#  -5.65311659 -5.61811277 -5.58310895 -5.54810513 -5.51310131 -5.4780975
#  -5.44309368 -5.40808986 -5.37308604 -5.33808222 -5.30307841 -5.26807459
#  -5.23307077 -5.19806695 -5.16306314 -5.12805932 -5.0930555  -5.05805168
#  -5.02304786 -4.98804405 -4.95304023 -4.91803641 -4.88303259 -4.84802877
#  -4.81302496 -4.77802114 -4.74301732 -4.7080135  -4.67300969 -4.63800587
#  -4.60300205 -4.56799823 -4.53299441 -4.4979906  -4.46298678 -4.42798296
#  -4.39297914 -4.35797532 -4.32297151 -4.28796769 -4.25296387 -4.21796005
#  -4.18295624 -4.14795242 -4.1129486  -4.07794478 -4.04294096 -4.00793715
#  -3.97293333 -3.93792951 -3.90292569 -3.86792187 -3.83291806 -3.79791424
#  -3.76291042 -3.7279066  -3.69290278 -3.65789897 -3.62289515 -3.58789133
# ...

# %%
import time
from math import pi
x=np.linspace(-2*pi,2*pi,360)
fx=np.log(x)
plt.plot(x,fx)
plt.show()
print(x)
# Out:
# C:\Users\ANKIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log
#   after removing the cwd from sys.path.
# [-6.28318531 -6.24818149 -6.21317767 -6.17817385 -6.14317004 -6.10816622
#  -6.0731624  -6.03815858 -6.00315476 -5.96815095 -5.93314713 -5.89814331
#  -5.86313949 -5.82813567 -5.79313186 -5.75812804 -5.72312422 -5.6881204
#  -5.65311659 -5.61811277 -5.58310895 -5.54810513 -5.51310131 -5.4780975
#  -5.44309368 -5.40808986 -5.37308604 -5.33808222 -5.30307841 -5.26807459
#  -5.23307077 -5.19806695 -5.16306314 -5.12805932 -5.0930555  -5.05805168
#  -5.02304786 -4.98804405 -4.95304023 -4.91803641 -4.88303259 -4.84802877
#  -4.81302496 -4.77802114 -4.74301732 -4.7080135  -4.67300969 -4.63800587
#  -4.60300205 -4.56799823 -4.53299441 -4.4979906  -4.46298678 -4.42798296
#  -4.39297914 -4.35797532 -4.32297151 -4.28796769 -4.25296387 -4.21796005
#  -4.18295624 -4.14795242 -4.1129486  -4.07794478 -4.04294096 -4.00793715
# ...

# %%
import time
from math import pi
x=np.linspace(-2*pi,2*pi,360)
fx=np.sqrt(x)
plt.plot(x,fx)
plt.show()
print(x)
# Out:
# C:\Users\ANKIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sqrt
#   after removing the cwd from sys.path.
# [-6.28318531 -6.24818149 -6.21317767 -6.17817385 -6.14317004 -6.10816622
#  -6.0731624  -6.03815858 -6.00315476 -5.96815095 -5.93314713 -5.89814331
#  -5.86313949 -5.82813567 -5.79313186 -5.75812804 -5.72312422 -5.6881204
#  -5.65311659 -5.61811277 -5.58310895 -5.54810513 -5.51310131 -5.4780975
#  -5.44309368 -5.40808986 -5.37308604 -5.33808222 -5.30307841 -5.26807459
#  -5.23307077 -5.19806695 -5.16306314 -5.12805932 -5.0930555  -5.05805168
#  -5.02304786 -4.98804405 -4.95304023 -4.91803641 -4.88303259 -4.84802877
#  -4.81302496 -4.77802114 -4.74301732 -4.7080135  -4.67300969 -4.63800587
#  -4.60300205 -4.56799823 -4.53299441 -4.4979906  -4.46298678 -4.42798296
#  -4.39297914 -4.35797532 -4.32297151 -4.28796769 -4.25296387 -4.21796005
#  -4.18295624 -4.14795242 -4.1129486  -4.07794478 -4.04294096 -4.00793715
# ...

# %%
fig=plt.figure()

g1= fig.add_subplot(2,2,1)
g1.plot(data['BasePay'],data['TotalPay'])
g1.scatter(data['BasePay'],data['TotalPay'],color='pink')


g2= fig.add_subplot(2,2,2)
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

g3= fig.add_subplot(2,1,2)
g3.plot(data['OtherPay'],data['TotalPay'],color='red')
g3.scatter(data['OtherPay'],data['TotalPay'])

plt.tight_layout()

# %%
fig=plt.figure()

g1= fig.add_subplot(2,2,1)
g1.plot(data['BasePay'],data['TotalPay'])
g1.scatter(data['BasePay'],data['TotalPay'],color='pink')


g2= fig.add_subplot(2,2,2)
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

g3= fig.add_subplot(2,2,3)
g3.plot(data['OtherPay'],data['TotalPay'],color='red')
g3.scatter(data['OtherPay'],data['TotalPay'])

g4= fig.add_subplot(2,2,4)
g4.plot(data['BasePay'],data['TotalPay'])
g4.scatter(data['BasePay'],data['TotalPay'],color='pink')


plt.tight_layout()

# %%
fig=plt.figure()

g1= fig.add_subplot(3,1,1)
g1.plot(data['BasePay'],data['TotalPay'])
g1.scatter(data['BasePay'],data['TotalPay'],color='pink')


g2= fig.add_subplot(3,1,2)
g2.plot(data['OtherPay'],data['TotalPay'],color='green')
g2.scatter(data['OtherPay'],data['TotalPay'])

g3= fig.add_subplot(3,1,3)
g3.plot(data['OtherPay'],data['TotalPay'],color='red')
g3.scatter(data['OtherPay'],data['TotalPay'])



plt.tight_layout()
