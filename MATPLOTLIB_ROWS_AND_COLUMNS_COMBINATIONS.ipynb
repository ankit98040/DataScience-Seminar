# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ecom = pd.read_csv('Ecommerce Customers')

# %%
ecom.head(20)
# Out:
#                             Email  \
# 0       mstephenson@fernandez.com
# 1               hduke@hotmail.com
# 2                pallen@yahoo.com
# 3         riverarebecca@gmail.com
# 4   mstephens@davidson-herman.com
# 5          alvareznancy@lucas.biz
# 6           katherine20@yahoo.com
# 7              awatkins@yahoo.com
# 8     vchurch@walter-martinez.com
# 9                bonnie69@lin.biz
# 10          andrew06@peterson.com
# 11         ryanwerner@freeman.biz
# 12              knelson@gmail.com
# 13          wrightpeter@yahoo.com
# 14          taylormason@gmail.com
# 15            jstark@anderson.com
# 16            wjennings@gmail.com
# 17       rebecca45@hale-bauer.biz
# 18        alejandro75@hotmail.com
# 19         samuel46@love-west.net
#
#                                               Address            Avatar  \
# 0        835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1      4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# ...

# %%
ecom=ecom.head(20)

# %%
fig=plt.figure()

g1= fig.add_subplot(1,2,1)
g1.plot(ecom['Avg. Session Length'],ecom['Time on App'])
g1.scatter(ecom['Avg. Session Length'],ecom['Time on App'],color='pink')


g2= fig.add_subplot(1,2,2)
g2.plot(ecom['Time on App'],ecom['Avg. Session Length'],color='green')
g2.scatter(ecom['Time on App'],ecom['Avg. Session Length'])

plt.tight_layout()

# %%
fig=plt.figure()

g1= fig.add_subplot(2,1,1)
g1.plot(ecom['Avg. Session Length'],ecom['Time on App'])
g1.scatter(ecom['Avg. Session Length'],ecom['Time on App'],color='pink')


g2= fig.add_subplot(2,1,2)
g2.plot(ecom['Time on App'],ecom['Avg. Session Length'],color='green')
g2.scatter(ecom['Time on App'],ecom['Avg. Session Length'])

plt.tight_layout()

# %%
fig=plt.figure()

g1= fig.add_subplot(1,2,1)
g1.plot(ecom['Time on App'],ecom['Time on Website'])
g1.scatter(ecom['Time on App'],ecom['Time on Website'],color='pink')


g2= fig.add_subplot(1,2,2)
g2.plot(ecom['Time on Website'],ecom['Time on App'],color='green')
g2.scatter(ecom['Time on Website'],ecom['Time on App'])

plt.tight_layout()

# %%
fig=plt.figure()

g1= fig.add_subplot(2,2,1)
g1.plot(ecom['Time on App'],ecom['Time on Website'])
g1.scatter(ecom['Time on App'],ecom['Time on Website'],color='pink')


g2= fig.add_subplot(2,2,2)
g2.plot(ecom['Time on Website'],ecom['Time on App'],color='green')
g2.scatter(ecom['Time on Website'],ecom['Time on App'])

plt.tight_layout()

# %%
fig=plt.figure()

fig.patch.set_facecolor('gray')

g1= fig.add_subplot(2,2,1)
g1.plot(ecom['Time on App'],ecom['Time on Website'])
g1.scatter(ecom['Time on App'],ecom['Time on Website'],color='pink')


g2= fig.add_subplot(2,2,2)
g2.plot(ecom['Time on Website'],ecom['Time on App'],color='green')
g2.scatter(ecom['Time on Website'],ecom['Time on App'])

g3= fig.add_subplot(2,2,3)
g3.plot(ecom['Length of Membership'],ecom['Yearly Amount Spent'],color='blue')
g3.scatter(ecom['Length of Membership'],ecom['Yearly Amount Spent'])

g4= fig.add_subplot(2,2,4)
g4.plot(ecom['Yearly Amount Spent'],ecom['Length of Membership'],color='red')
g4.scatter(ecom['Yearly Amount Spent'],ecom['Length of Membership'])

plt.tight_layout()

# %%
fig=plt.figure()

fig.patch.set_facecolor('gray')

g1= fig.add_subplot(2,2,1)
g1.plot(ecom['Time on App'],ecom['Time on Website'])
g1.scatter(ecom['Time on App'],ecom['Time on Website'],color='pink')


g2= fig.add_subplot(2,2,2)
g2.plot(ecom['Time on Website'],ecom['Time on App'],color='green')
g2.scatter(ecom['Time on Website'],ecom['Time on App'])

g3= fig.add_subplot(2,1,2)
g3.plot(ecom['Length of Membership'],ecom['Yearly Amount Spent'],color='blue')
g3.scatter(ecom['Length of Membership'],ecom['Yearly Amount Spent'])

plt.tight_layout()

# %%
fig=plt.figure()

fig.patch.set_facecolor('gray')

g1= fig.add_subplot(2,2,1)
g1.plot(ecom['Time on App'],ecom['Time on Website'])
g1.scatter(ecom['Time on App'],ecom['Time on Website'],color='pink')


g2= fig.add_subplot(2,2,2)
g2.plot(ecom['Time on Website'],ecom['Time on App'],color='green')
g2.scatter(ecom['Time on Website'],ecom['Time on App'])

g3= fig.add_subplot(2,3,4)
g3.plot(ecom['Length of Membership'],ecom['Yearly Amount Spent'],color='blue')
g3.scatter(ecom['Length of Membership'],ecom['Yearly Amount Spent'])

g4= fig.add_subplot(2,3,5)
g4.plot(ecom['Yearly Amount Spent'],ecom['Length of Membership'],color='red')
g4.scatter(ecom['Yearly Amount Spent'],ecom['Length of Membership'])

g5= fig.add_subplot(2,3,6)
g5.plot(ecom['Avg. Session Length'],ecom['Time on App'],color='yellow')
g5.scatter(ecom['Avg. Session Length'],ecom['Time on App'])

plt.tight_layout()
# Out:
# J:\ProgramData\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:345: UserWarning: tight_layout not applied: number of columns in subplot specifications mustbe multiples of one another.
#   warnings.warn('tight_layout not applied: '

# %%
fig=plt.figure()

fig.patch.set_facecolor('gray')

g1= fig.add_subplot(2,1,1)
g1.plot(ecom['Time on App'],ecom['Time on Website'])
g1.scatter(ecom['Time on App'],ecom['Time on Website'],color='pink')


g2= fig.add_subplot(2,3,4)
g2.plot(ecom['Time on Website'],ecom['Time on App'],color='green')
g2.scatter(ecom['Time on Website'],ecom['Time on App'])

g3= fig.add_subplot(2,3,5)
g3.plot(ecom['Length of Membership'],ecom['Yearly Amount Spent'],color='blue')
g3.scatter(ecom['Length of Membership'],ecom['Yearly Amount Spent'])

g4= fig.add_subplot(2,3,6)
g4.plot(ecom['Yearly Amount Spent'],ecom['Length of Membership'],color='red')
g4.scatter(ecom['Yearly Amount Spent'],ecom['Length of Membership'])

plt.tight_layout()

# %%
fig=plt.figure()

fig.patch.set_facecolor('gray')

g1= fig.add_subplot(4,2,1)
g1.plot(ecom['Time on App'],ecom['Time on Website'])
g1.scatter(ecom['Time on App'],ecom['Time on Website'],color='pink')


g2= fig.add_subplot(4,2,2)
g2.plot(ecom['Time on Website'],ecom['Time on App'],color='green')
g2.scatter(ecom['Time on Website'],ecom['Time on App'])

g3= fig.add_subplot(4,2,3)
g3.plot(ecom['Length of Membership'],ecom['Yearly Amount Spent'],color='blue')
g3.scatter(ecom['Length of Membership'],ecom['Yearly Amount Spent'])

g4= fig.add_subplot(4,2,5)
g4.plot(ecom['Yearly Amount Spent'],ecom['Length of Membership'],color='red')
g4.scatter(ecom['Yearly Amount Spent'],ecom['Length of Membership'])

g5= fig.add_subplot(4,2,6)
g5.plot(ecom['Avg. Session Length'],ecom['Time on App'],color='yellow')
g5.scatter(ecom['Avg. Session Length'],ecom['Time on App'])

g6= fig.add_subplot(4,1,4)
g6.plot(ecom['Avg. Session Length'],ecom['Time on Website'],color='violet')
g6.scatter(ecom['Avg. Session Length'],ecom['Time on Website'])

plt.tight_layout()

# %%
fig=plt.figure()

fig.patch.set_facecolor('gray')

g1= fig.add_subplot(4,2,1)
g1.plot(ecom['Time on App'],ecom['Time on Website'])
g1.scatter(ecom['Time on App'],ecom['Time on Website'],color='pink')


g2= fig.add_subplot(4,2,2)
g2.plot(ecom['Time on Website'],ecom['Time on App'],color='green')
g2.scatter(ecom['Time on Website'],ecom['Time on App'])

g3= fig.add_subplot(4,2,3)
g3.plot(ecom['Length of Membership'],ecom['Yearly Amount Spent'],color='blue')
g3.scatter(ecom['Length of Membership'],ecom['Yearly Amount Spent'])

g4= fig.add_subplot(4,2,5)
g4.plot(ecom['Yearly Amount Spent'],ecom['Length of Membership'],color='red')
g4.scatter(ecom['Yearly Amount Spent'],ecom['Length of Membership'])

g5= fig.add_subplot(4,2,(4,6))
g5.plot(ecom['Avg. Session Length'],ecom['Time on App'],color='yellow')
g5.scatter(ecom['Avg. Session Length'],ecom['Time on App'])

g6= fig.add_subplot(4,1,4)
g6.plot(ecom['Avg. Session Length'],ecom['Time on Website'],color='violet')
g6.scatter(ecom['Avg. Session Length'],ecom['Time on Website'])

plt.tight_layout()

# %%
fig=plt.figure()

fig.patch.set_facecolor('gray')

g1= fig.add_subplot(1,2,1, facecolor = 'skyblue')
g1.plot(ecom['Time on App'],ecom['Time on Website'])
g1.scatter(ecom['Time on App'],ecom['Time on Website'],color='pink')


g2= fig.add_subplot(3,2,2, facecolor = 'yellow')
g2.plot(ecom['Time on Website'],ecom['Time on App'],color='green')
g2.scatter(ecom['Time on Website'],ecom['Time on App'])

g3= fig.add_subplot(3,2,4, facecolor = 'skyblue')
g3.plot(ecom['Length of Membership'],ecom['Yearly Amount Spent'],color='blue')
g3.scatter(ecom['Length of Membership'],ecom['Yearly Amount Spent'])

g4= fig.add_subplot(3,2,6, facecolor = 'yellow')
g4.plot(ecom['Yearly Amount Spent'],ecom['Length of Membership'],color='red')
g4.scatter(ecom['Yearly Amount Spent'],ecom['Length of Membership'])

plt.tight_layout()

# %%
fig=plt.figure()

fig.patch.set_facecolor('gray')

g1= fig.add_subplot(1,3,1)
g1.plot(ecom['Time on App'],ecom['Time on Website'])
g1.scatter(ecom['Time on App'],ecom['Time on Website'],color='pink')


g2= fig.add_subplot(1,3,2)
g2.plot(ecom['Time on Website'],ecom['Time on App'],color='green')
g2.scatter(ecom['Time on Website'],ecom['Time on App'])

g3= fig.add_subplot(3,3,3)
g3.plot(ecom['Length of Membership'],ecom['Yearly Amount Spent'],color='blue')
g3.scatter(ecom['Length of Membership'],ecom['Yearly Amount Spent'])

g4= fig.add_subplot(3,3,6)
g4.plot(ecom['Yearly Amount Spent'],ecom['Length of Membership'],color='red')
g4.scatter(ecom['Yearly Amount Spent'],ecom['Length of Membership'])

g5= fig.add_subplot(3,3,9)
g5.plot(ecom['Avg. Session Length'],ecom['Time on App'],color='yellow')
g5.scatter(ecom['Avg. Session Length'],ecom['Time on App'])

plt.tight_layout()

# %%
fig=plt.figure()

fig.patch.set_facecolor('gray')

g1= fig.add_subplot(1,3,1)
g1.plot(ecom['Time on App'],ecom['Time on Website'])
g1.scatter(ecom['Time on App'],ecom['Time on Website'],color='pink')


g2= fig.add_subplot(1,3,3)
g2.plot(ecom['Time on Website'],ecom['Time on App'],color='green')
g2.scatter(ecom['Time on Website'],ecom['Time on App'])

g3= fig.add_subplot(3,3,2)
g3.plot(ecom['Length of Membership'],ecom['Yearly Amount Spent'],color='blue')
g3.scatter(ecom['Length of Membership'],ecom['Yearly Amount Spent'])

g4= fig.add_subplot(3,3,5)
g4.plot(ecom['Yearly Amount Spent'],ecom['Length of Membership'],color='red')
g4.scatter(ecom['Yearly Amount Spent'],ecom['Length of Membership'])

g5= fig.add_subplot(3,3,8)
g5.plot(ecom['Avg. Session Length'],ecom['Time on App'],color='yellow')
g5.scatter(ecom['Avg. Session Length'],ecom['Time on App'])

plt.tight_layout()
